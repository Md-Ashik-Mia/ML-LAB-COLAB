# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Ashik-Mia/ML-LAB-COLAB/blob/main/213002158_CSE312_221D13_LabReport01_LinearRegression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=df.iloc[:,:-1]
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
for column in x :
  # print(df[column].mean())
  # print(df[column])
    df[column]=df[column].replace(0,df[column].mean())
df.head()
# Replace zero values in key features with column mean or median. //done here
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
highestGlucoseValue =df["Glucose"].max()
df.iloc[0,1]=highestGlucoseValue
df.head()
# Replace the first row’s glucose value with the maximum from the glucose column. //done here
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    199.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
minimumAge =df["Age"].min()
minimumGlucose =df["Glucose"].min()
print(minimumAge,minimumGlucose)
# Out:
# 21 44.0
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age

# %%
# for column in x :
  # if column=="Age":
index=0
for i in df["Age"]:
    # print(index, i)
    if(i==minimumAge):
      df.iloc[index,1]=minimumGlucose
    index=index+1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    199.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     44.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, train_size=0.2, random_state=0)
# preprocessing data here

# %%
from re import RegexFlag
from sklearn.linear_model import LinearRegression
regressor =LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# -0.9311638900536579
# [ 0.0201382   0.00567994  0.00260246 -0.00194532 -0.00061185  0.01538345
#   0.16088092 -0.00345216]

# %%
import numpy as np
y_pred=regressor.predict(x_test)
y_pred=np.round(y_pred)
# Use Linear Regression to predict the binary Outcome. Round predictions to the nearest integer (0 or 1). //done here

updatedf=pd.DataFrame({"Actual":y_test , "Predict":y_pred})
print(updatedf)
# Out:
#      Actual  Predict
# 661       1      1.0
# 122       0      0.0
# 113       0      0.0
# 14        1      0.0
# 529       0      0.0
# ..      ...      ...
# 110       1      1.0
# 149       0      0.0
# 152       1      1.0
# 528       0      0.0
# 461       0     -0.0
#
# [615 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score , confusion_matrix,precision_score,recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
confusion=confusion_matrix(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
fscore = f1_score(y_test,y_pred)
print(accuracy)
print(confusion)
print(precision)
print(recall)
print(fscore)
# Out:
# 0.7626016260162601
# [[354  42]
#  [104 115]]
# 0.732484076433121
# 0.5251141552511416
# 0.6117021276595744
